# %%
s = ""
for i in range(1, 100 + 1):
    if (i >= 16 and i <= 18) or  (i >= 39 and i <= 42) or (i >= 50 and i <= 55) or (i >= 93 and i <= 99):
        s += "x"
    else:
        s += "o"
s
# Out:
# 'oooooooooooooooxxxooooooooooooooooooooxxxxoooooooxxxxxxoooooooooooooooooooooooooooooooooooooxxxxxxxo'

# %%
def count(n):
    count = 0
    for i in range(10, n + 1):
        str_i = str(i)
        biggest = True
        for s in str_i[1:]:
            if int(str_i[0]) <= int(s):
                biggest = False
                break
        if biggest:
            print(i)
            count += 1
    return count

# %%
count(9999)
# Out:
# 2355

# %%
count(999)
# Out:
# 10
# 20
# 21
# 30
# 31
# 32
# 40
# 41
# 42
# 43
# 50
# 51
# 52
# 53
# 54
# 60
# 61
# 62
# 63
# 64
# 65
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 100
# 200
# 201
# 210
# 211
# 300
# 301
# 302
# 310
# 311
# 312
# 320
# 321
# 322
# 400
# 401
# 402
# 403
# 410
# 411
# 412
# 413
# 420
# 421
# 422
# 423
# 430
# 431
# 432
# 433
# 500
# 501
# 502
# 503
# 504
# 510
# 511
# 512
# 513
# 514
# 520
# 521
# 522
# 523
# 524
# 530
# 531
# 532
# 533
# 534
# 540
# 541
# 542
# 543
# 544
# 600
# 601
# 602
# 603
# 604
# 605
# 610
# 611
# 612
# 613
# 614
# 615
# 620
# 621
# 622
# 623
# 624
# 625
# 630
# 631
# 632
# 633
# 634
# 635
# 640
# 641
# 642
# 643
# 644
# 645
# 650
# 651
# 652
# 653
# 654
# 655
# 700
# 701
# 702
# 703
# 704
# 705
# 706
# 710
# 711
# 712
# 713
# 714
# 715
# 716
# 720
# 721
# 722
# 723
# 724
# 725
# 726
# 730
# 731
# 732
# 733
# 734
# 735
# 736
# 740
# 741
# 742
# 743
# 744
# 745
# 746
# 750
# 751
# 752
# ...

# %%
count(210)
# Out:
# 49

# %%
count(96)
# Out:
# 43
